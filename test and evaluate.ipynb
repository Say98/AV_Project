# %%
#Mount your Google drive account
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Change directory where there are all the file needed
# %cd '/content/gdrive/My Drive/'
# Out:
# /content/gdrive/My Drive

# %%
#Run this to obtain the results of prediction (.csv)
#Specify all the file needed:
# --data -> path to groundtruth csv file
# --images -> directory of testset folder in which images are contained
# --results -> filename of output results
# --model -> path to the model file .h5
# !python3 test.py --data testset/val_labels.csv --images testset/validation_set/ --results vgg_results.csv --model models/vgg_model_2022_01_07_13_53.h5
# Out:
# 2022-01-11 17:52:39.979325: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Done

# %%
#Run this to obtain confusion matrix and all the accuracy metrics
#Specify the file needed:
# --gt_path -> path to groundtruth csv file
# --res_path -> path to predictions results csv file
# !python3 evaluate.py --gt_path testset/val_labels.csv --res_path vgg_results.csv
# Out:
# 3225
# 3225
# beard_confusion_matrix
#  [[2614   13]
#  [  19  579]]
# moustache_confusion_matrix
#  [[2887   15]
#  [  15  308]]
# glasses_confusion_matrix
#  [[2287    4]
#  [   3  931]]
# +-----------------------------+-------+
# |            Metric           | Value |
# +-----------------------------+-------+
# |        beard_accuracy       |  0.99 |
# |   beard_balanced_accuracy   | 0.982 |
# |      moustache_accuracy     | 0.991 |
# | moustache_balanced_accuracy | 0.974 |
# |       glasses_accuracy      | 0.998 |
# |  glasses_balanced_accuracy  | 0.998 |
# |         avg_accuracy        | 0.993 |
# |    avg_balanced_accuracy    | 0.984 |
# |             fas             | 1.977 |
# +-----------------------------+-------+
